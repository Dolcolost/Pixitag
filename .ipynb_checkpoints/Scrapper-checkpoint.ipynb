# %%
import requests
from bs4 import BeautifulSoup
import json
from datetime import date
from pymongo import MongoClient

# %%
url = "http://www.pixiv.net/ranking.php?mode=daily"
response = requests.get(url)
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36', 
          'password': 'rd.)T6vF',
          'pixiv_id' : 'flicfloclol@hotmail.fr'}
response = requests.get(url, headers=headers, timeout = 10)

parse = url.split('&')

imageId = []


if (len(parse) == 1):
    rankingDate = str(date.today())   
else:
    rankingDate = parse[1][5:9] + '-' + parse[1][9:11] + '-' + parse[1][11:13]


soup = BeautifulSoup(response.text)
links = []

# for single illustration (different class)
for link in soup.find_all('a', class_="work _work"):
    links.append("https://www.pixiv.net/ajax/illust/" + link.get('href').split('/')[2] + "?lang=en")
    imageId.append(link.get('href').split('/')[2])
    
# for multiple illustrations (different class)\n",
for link in soup.find_all('a', class_="work _work multiple"):
    links.append("https://www.pixiv.net/ajax/illust/" + link.get('href').split('/')[2] + "?lang=en")
    imageId.append(link.get('href').split('/')[2])

# %%
#url = "https://www.pixiv.net/ajax/ill?lang=enust/89101579"

data = []

counter = 0
imageCounter = 0

for url in links:

    response = requests.get(url, headers=headers, timeout = 100)
    jsonData = json.loads(response.text)

    tags = []

    for i in jsonData['body']['tags']['tags']:
        data.append({})
        if 'translation' not in i:
            if 'romaji' not in i:
                data[counter].update({'tag': i['tag']})
            else:
                data[counter].update({'tag': i['romaji']})
        else:
            data[counter].update({'tag': i['translation']['en']})
            
        data[counter].update({'date' : rankingDate})
        data[counter].update({'username' : jsonData['body']['userName']})
        data[counter].update({'imageId' : imageId[imageCounter]})
        counter += 1
    imageCounter += 1
    

print(data)
# Out:
# [{'tag': 'VOCALOID', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'hatsune miku', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'ODDS&ENDS', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'korehaiihatsune', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'Miku must be an angel', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'Vocaloid 10000+ bookmarks', 'date': '2021-04-17', 'username': 'おむたつ/omutatsu', 'imageId': '89155451'}, {'tag': 'Gold Ship', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'gorushi', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'Uma Musume Pretty Derby', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'horse girl', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'high boots', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'korekosogago-rudoshippu', 'date': '2021-04-17', 'username': 'Nardack', 'imageId': '89174625'}, {'tag': 'armpits', 'date': '2021-04-17', 'username
    ids.append(document)
    print(document)
# Out:
# {'_id': 'original', 'nb': 14}
# {'_id': 'girl', 'nb': 6}
# {'_id': 'Uma Musume Pretty Derby', 'nb': 5}
# {'_id': 'Fate/GrandOrder', 'nb': 4}
# {'_id': 'FGO', 'nb': 4}
# {'_id': 'original 5000+ bookmarks', 'nb': 3}
# {'_id': 'Virtual Youtuber', 'nb': 3}
# {'_id': 'clothed breasts', 'nb': 3}
# {'_id': 'Gold Ship (UMPD)', 'nb': 3}
# {'_id': 'evangelion', 'nb': 3}
# {'_id': 'Fate/GO 1000+ bookmarks', 'nb': 3}
# {'_id': 'umaamusumepurithi-da-bi-sennyu-za-iri', 'nb': 2}
# {'_id': 'Genshin Impact', 'nb': 2}
# {'_id': 'subarashikihokkorinosekai', 'nb': 2}
# {'_id': 'Evangelion New Theatrical Release', 'nb': 2}
# {'_id': 'Evangelion 1000+ bookmarks', 'nb': 2}
# {'_id': 'evagosennyu-za-zuiri', 'nb': 2}
# {'_id': 'Shikinami Asuka Langley', 'nb': 2}
# {'_id': 'Pokémon', 'nb': 2}
# {'_id': 'Ashiya Douman (Fate)', 'nb': 2}
# {'_id': 'Nijisanji', 'nb': 2}
# {'_id': 'creation', 'nb': 2}
# {'_id': 'korekosogago-rudoshippu', 'nb': 2}
# {'_id': 'Project Sekai', 'nb': 2}
# {'_id': 'work illustration', 'nb': 2}
# {'_id': 'plugsuit', 'nb': 2}
# {'_id': 'Lumine (Genshin Impact)', 'nb': 2}
# {'_id': 'young girl', 'nb': 2}
# {'_id': 'Watanabe no Tsuna (Fate)', 'nb': 2}
# {'_id': 'alluring face', 'nb': 2}
# {'_id': 'horse girl', 'nb': 2}
# {'_id': 'neon genesis evangelion', 'nb': 2}
# {'_id': 'Virtual YouTuber 10000+ bookmarks', 'nb': 1}
# {'_id': 'oda nobunaga', 'nb': 1}
# {'_id': 'cleavage', 'nb': 1}
# {'_id': 'Homura Akemi', 'nb': 1}
# {'_id': 'jinnruipokannkeikaku', 'nb': 1}
# {'_id': 'I want to go here', 'nb': 1}
# {'_id': 'Japanese-style', 'nb': 1}
# {'_id': 'heavenly ass', 'nb': 1}
# {'_id': 'beautiful', 'nb': 1}
# {'_id': 'fuukeigosennyu-za-zuiri', 'nb': 1}
# {'_id': 'VOCALOID', 'nb': 1}
# {'_id': 'Gudako', 'nb': 1}
# {'_id': 'cynthia', 'nb': 1}
# {'_id': 'Sweets Bird', 'nb': 1}
# {'_id': 'Voyager (Fate)', 'nb': 1}
# {'_id': 'CHUNITHM', 'nb': 1}
# {'_id': 'ここに巣を作ろう', 'nb': 1}
# {'_id': 'hageshikudoui', 'nb': 1}
# {'_id': 'Marnie (Pokemon trainer)', 'nb': 1}
# {'_id': 'illustration', 'nb': 1}
# {'_id': 'Sherlock Holmes (Fate)', 'nb': 1}
# {'_id': 'shirokumasann', 'nb': 1}
# {'_id': 'muru', 'nb': 1}
# {'_id': 'hatsune miku', 'nb': 1}
# {'_id': 'Fate/GO 5000+ bookmarks', 'nb': 1}
# {'_id': 'short haircut', 'nb': 1}
# {'_id': 'VTuber', 'nb': 1}
# {'_id': 'Toxtricity', 'nb': 1}
# {'_id': '誰も消防車を呼ばないのである!', 'nb': 1}
# {'_id': 'human characters in Pokémon', 'nb': 1}
# {'_id': 'announcement', 'nb': 1}
# {'_id': 'sailor uniform', 'nb': 1}
# {'_id': 'ronnguayanami', 'nb': 1}
# {'_id': 'Nobunaga Oda (Fate)', 'nb': 1}
# {'_id': 'NL周回目', 'nb': 1}
# {'_id': 'Daiwa Scarlet (UMPD)', 'nb': 1}
# {'_id': 'Demon Slayer: Kimetsu no Yaiba', 'nb': 1}
# {'_id': 'ODDS&ENDS', 'nb': 1}
# {'_id': 'madao', 'nb': 1}
# {'_id': 'Edmond Dantes (Fate)', 'nb': 1}
# {'_id': 'Kama (Fate)', 'nb': 1}
# {'_id': 'purosekahyakuyu-za-zuiri', 'nb': 1}
# {'_id': 'against glass', 'nb': 1}
# {'_id': 'o-enn', 'nb': 1}
# {'_id': 'Minato Aqua', 'nb': 1}
# {'_id': 'cola exists', 'nb': 1}
# {'_id': '1', 'nb': 1}
# {'_id': 'evanngerionnbatoruirakonn', 'nb': 1}
# {'_id': 'Shinobu Kochou', 'nb': 1}
# {'_id': 'Hololive', 'nb': 1}
# {'_id': 'Mito Tsukino', 'nb': 1}
# {'_id': 'Kasumi Miwa', 'nb': 1}
# {'_id': '絵守未來Project', 'nb': 1}
# {'_id': '卵かけごはん', 'nb': 1}
# {'_id': 'あられーとり', 'nb': 1}
# {'_id': 'クマディアン', 'nb': 1}
# {'_id': 'purosekasennyu-za-zuiri', 'nb': 1}
# {'_id': 'Kuzuha (Nijisanji Gamers)', 'nb': 1}
# {'_id': 'Bea', 'nb': 1}
# {'_id': 'hands-on-hips', 'nb': 1}
# {'_id': 'armpits', 'nb': 1}
# {'_id': '｢みーつけた!｣', 'nb': 1}
# {'_id': '幸せの小鳥', 'nb': 1}
# {'_id': 'gloves', 'nb': 1}
# {'_id': 'abekobewakusei', 'nb': 1}
# {'_id': 'scenery', 'nb': 1}
# {'_id': 'OL', 'nb': 1}
# {'_id': 'Minato Aqua fanart', 'nb': 1}
# {'_id': 'seibetsushinnji', 'nb': 1}
# {'_id': '25-ji, Night Code de.', 'nb': 1}
# {'_id': 'Anastasia Nikolaevna Romanova (Fate)', 'nb': 1}
# {'_id': 'fox ears', 'nb': 1}
# {'_id': 'large breasts', 'nb': 1}
# {'_id': 'gorumaku', 'nb': 1}
# {'_id': 'Padparadscha', 'nb': 1}
# {'_id': 'siren', 'nb': 1}
# {'_id': 'high school girl', 'nb': 1}
# {'_id': 'witch', 'nb': 1}
# {'_id': '「やあ」', 'nb': 1}
# {'_id': 'casual clothes', 'nb': 1}
# {'_id': 'Hilda (Trainer)', 'nb': 1}
# {'_id': 'crossover 1000+ bookmarks', 'nb': 1}
# {'_id': 'korehaiihatsune', 'nb': 1}
# {'_id': 'Gold Ship', 'nb': 1}
# {'_id': 'Hilarious last', 'nb': 1}
# {'_id': 'otokonoko', 'nb': 1}
# {'_id': 'souji okita', 'nb': 1}
# {'_id': 'Miku must be an angel', 'nb': 1}
# {'_id': 'Saito Hajime (Fate)', 'nb': 1}
# {'_id': 'food', 'nb': 1}
# {'_id': 'first-rate breasts', 'nb': 1}
# {'_id': 'Mejiro McQueen (UMPD)', 'nb': 1}
# {'_id': 'boob tent', 'nb': 1}
# {'_id': 'foam', 'nb': 1}
# {'_id': '恋する(おとめ)の作り方', 'nb': 1}
# {'_id': 'あられーとりを探せ!', 'nb': 1}
# {'_id': 'Chiya', 'nb': 1}
# {'_id': 'Jujutsu Kaisen 5000+ bookmarks', 'nb': 1}
# {'_id': 'Promise of Wizard', 'nb': 1}
# {'_id': 'eva', 'nb': 1}
# {'_id': 'refined taste', 'nb': 1}
# {'_id': 'copyright', 'nb': 1}
# {'_id': 'mihorai', 'nb': 1}
# {'_id': '「似合う?」', 'nb': 1}
# {'_id': 'すいんぐ!!', 'nb': 1}
# {'_id': 'Caster Limbo', 'nb': 1}
# {'_id': '地雷系', 'nb': 1}
# {'_id': 'original works', 'nb': 1}
# {'_id': 'Pokémon 10000+ bookmarks', 'nb': 1}
# {'_id': 'original 7,500+ bookmarks', 'nb': 1}
# {'_id': 'moukoregahonnpenndeiiyo', 'nb': 1}
# {'_id': 'big butt', 'nb': 1}
# {'_id': 'yakizakana', 'nb': 1}
# {'_id': '可愛すぎるふぉーまる', 'nb': 1}
# {'_id': 'breasts', 'nb': 1}
# {'_id': 'まふえむ', 'nb': 1}
# {'_id': 'bellybutton', 'nb': 1}
# {'_id': 'high boots', 'nb': 1}
# {'_id': 'sakura', 'nb': 1}
# {'_id': 'hoping for a sequel', 'nb': 1}
# {'_id': 'gothic', 'nb': 1}
# {'_id': 'Mihono Bourbon (Uma Musume)', 'nb': 1}
# {'_id': 'くまっぷりん', 'nb': 1}
# {'_id': 'cherry blossoms', 'nb': 1}
# {'_id': 'Mizuki/Ena', 'nb': 1}
# {'_id': 'Nessa', 'nb': 1}
# {'_id': 'manga', 'nb': 1}
# {'_id': "Yamcha'd", 'nb': 1}
# {'_id': 'matou sakura', 'nb': 1}
# {'_id': 'Demon Slayer: Kimetsu no Yaiba 1000+ bookmarks', 'nb': 1}
# {'_id': 'チャップリーーン', 'nb': 1}
# {'_id': 'Genshin Impact 1000+ bookmarks', 'nb': 1}
# {'_id': 'half-up hairstyle', 'nb': 1}
# {'_id': 'umamusumepurithi-da-bi-ichimannyu-za-iri', 'nb': 1}
# {'_id': 'Caren C Hortensia', 'nb': 1}
# {'_id': 'ど〜こだ?', 'nb': 1}
# {'_id': 'ibu', 'nb': 1}
# {'_id': 'umamusumenoraisushawa-', 'nb': 1}
# {'_id': 'boob gap', 'nb': 1}
# {'_id': 'gorushi', 'nb': 1}
# {'_id': 'rei ayanami', 'nb': 1}
# {'_id': 'Vocaloid 10000+ bookmarks', 'nb': 1}
# {'_id': 'Jujutsu Kaisen', 'nb': 1}
# {'_id': 'knife', 'nb': 1}
# {'_id': 'pencil skirt', 'nb': 1}
# {'_id': 'ジャンクモール', 'nb': 1}
# {'_id': 'しろくまさん(フォーマルver.)', 'nb': 1}

# %%
#Get most 
cursor = collection.aggregate([
    #{"$match": {'date': '2021-04-17'}},
    {'$group': {
        '_id': {'username': '$username'},
        'images': {'$addToSet': '$imageId'}
    }},
    {'$project': {'nb': {'$size': '$images'}}},
    {'$sort': {'nb': -1}}
])
for document in cursor:
    ids.append(document)
    print(document)
# Out:
# {'_id': {'username': 'チャイ'}, 'nb': 5}
# {'_id': {'username': 'ポ～ン（出水ぽすか）'}, 'nb': 5}
# {'_id': {'username': '寺田てら'}, 'nb': 3}
# {'_id': {'username': 'TOKKYU'}, 'nb': 3}
# {'_id': {'username': 'スコッティ'}, 'nb': 3}
# {'_id': {'username': 'かわやばぐ'}, 'nb': 2}
# {'_id': {'username': 'sakimichan'}, 'nb': 2}
# {'_id': {'username': 'ぽむ'}, 'nb': 2}
# {'_id': {'username': '上山道郎'}, 'nb': 2}
# {'_id': {'username': 'AU'}, 'nb': 2}
# {'_id': {'username': '村カルキ'}, 'nb': 2}
# {'_id': {'username': 'Saclia'}, 'nb': 2}
# {'_id': {'username': 'EB十'}, 'nb': 2}
# {'_id': {'username': 'きの'}, 'nb': 1}
# {'_id': {'username': '旧都なぎ'}, 'nb': 1}
# {'_id': {'username': 'Aoi Ogata'}, 'nb': 1}
# {'_id': {'username': 'あるてら'}, 'nb': 1}
# {'_id': {'username': '河合朗🎀短編集発売中'}, 'nb': 1}
# {'_id': {'username': 'Rosuuri'}, 'nb': 1}
# {'_id': {'username': 'ハラダミユキ'}, 'nb': 1}
# {'_id': {'username': '色素'}, 'nb': 1}
# {'_id': {'username': 'Nengoro(ネんごろぅ)'}, 'nb': 1}
# {'_id': {'username': 'かれい'}, 'nb': 1}
# {'_id': {'username': '花ヶ田 / hanagata'}, 'nb': 1}
# {'_id': {'username': 'rioka'}, 'nb': 1}
# {'_id': {'username': '山吹色'}, 'nb': 1}
# {'_id': {'username': '河CY'}, 'nb': 1}
# {'_id': {'username': '猫屋敷ぷしお'}, 'nb': 1}
# {'_id': {'username': 'ロイスト'}, 'nb': 1}
# {'_id': {'username': 'にもし🌞'}, 'nb': 1}
# {'_id': {'username': 'torino'}, 'nb': 1}
# {'_id': {'username': 'ポテトルス'}, 'nb': 1}
# {'_id': {'username': 'コーラ'}, 'nb': 1}
# {'_id': {'username': '室埴 ポコ'}, 'nb': 1}
# {'_id': {'username': '千夜QYS3'}, 'nb': 1}
# {'_id': {'username': 'Lpip'}, 'nb': 1}
# {'_id': {'username': '孟達'}, 'nb': 1}
# {'_id': {'username': 'lack'}, 'nb': 1}
# {'_id': {'username': 'おゆゆ'}, 'nb': 1}
# {'_id': {'username': '茶ごま'}, 'nb': 1}
# {'_id': {'username': '富士茄 鷹'}, 'nb': 1}
# {'_id': {'username': 'SWAV'}, 'nb': 1}
# {'_id': {'username': 'xiwa'}, 'nb': 1}
# {'_id': {'username': '逢編いあむ'}, 'nb': 1}
# {'_id': {'username': '色谷あすか'}, 'nb': 1}
# {'_id': {'username': '碧風羽 BOOTH店オープン'}, 'nb': 1}
# {'_id': {'username': 'レドル'}, 'nb': 1}
# {'_id': {'username': 'HARURI / 仕事募集中'}, 'nb': 1}
# {'_id': {'username': 'hg6'}, 'nb': 1}
# {'_id': {'username': 'az./万丈梓'}, 'nb': 1}
# {'_id': {'username': 'しぐれうい'}, 'nb': 1}
# {'_id': {'username': 'ジェット虚無僧'}, 'nb': 1}
# {'_id': {'username': 'おむたつ/omutatsu'}, 'nb': 1}
# {'_id': {'username': '我美蘭☆FGOAC概念礼装'}, 'nb': 1}
# {'_id': {'username': '佐倉おりこ@単行本発売中'}, 'nb': 1}
# {'_id': {'username': '白滝'}, 'nb': 1}
# {'_id': {'username': 'ガしガし'}, 'nb': 1}
# {'_id': {'username': '据え置き'}, 'nb': 1}
# {'_id': {'username': '梦夏shimmer'}, 'nb': 1}
# {'_id': {'username': 'Kaneni'}, 'nb': 1}
# {'_id': {'username': 'Nine'}, 'nb': 1}
# {'_id': {'username': '㈲もぺ'}, 'nb': 1}
# {'_id': {'username': 'ミミス'}, 'nb': 1}
# {'_id': {'username': 'まふゆ'}, 'nb': 1}
# {'_id': {'username': 'あんのあーの'}, 'nb': 1}
# {'_id': {'username': 'ArseniXC'}, 'nb': 1}
# {'_id': {'username': 'TanDo'}, 'nb': 1}
# {'_id': {'username': 'うさもち。'}, 'nb': 1}
# {'_id': {'username': '純白可憐'}, 'nb': 1}
# {'_id': {'username': '九十九'}, 'nb': 1}
# {'_id': {'username': 'ケースワベ【K-SUWABE】'}, 'nb': 1}
# {'_id': {'username': 'サメヤマ次郎'}, 'nb': 1}
# {'_id': {'username': 'Nardack'}, 'nb': 1}
# {'_id': {'username': 'ショットガンマン'}, 'nb': 1}
# {'_id': {'username': 'sena'}, 'nb': 1}
# {'_id': {'username': 'トーコ'}, 'nb': 1}
# {'_id': {'username': 'oekakizuki'}, 'nb': 1}
# {'_id': {'username': 'きさらぎゆり'}, 'nb': 1}
# {'_id': {'username': 'さかいワカ🌎お仕事募集中'}, 'nb': 1}
# {'_id': {'username': '旳---'}, 'nb': 1}
# {'_id': {'username': 'Jia Ma'}, 'nb': 1}
# {'_id': {'username': '海島千本'}, 'nb': 1}
# {'_id': {'username': '*zoff'}, 'nb': 1}
# {'_id': {'username': 'ナコモ'}, 'nb': 1}
# {'_id': {'username': 'Lunacle @お仕事募集中'}, 'nb': 1}
# {'_id': {'username': '遠坂あさぎ'}, 'nb': 1}
# {'_id': {'username': 'ケイケイ・T'}, 'nb': 1}

# %%
cursor = collection.distinct('imageId', {'username': 'チャイ'})
ids = []
for document in cursor:
    ids.append(document)
    print(document)
# Out:
# 88835022
# 88860800
# 89150224
# 89169421
# 89188590
